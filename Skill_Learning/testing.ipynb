# %%
import os
import numpy as np
import argparse
from sklearn.svm import OneClassSVM
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support, classification_report
from sklearn.metrics import confusion_matrix
import joblib
from skill_helpers import *
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import argparse
# ----> 4 from sklearn.svm import OneClassSVM
#       5 from sklearn.preprocessing import StandardScaler
#       6 from sklearn.pipeline import make_pipeline
#
# File ~/anaconda3/envs/SOTA/lib/python3.10/site-packages/sklearn/__init__.py:84
#      70     # We are not importing the rest of scikit-learn during the build
#      71     # process, as it may not be compiled yet
#      72 else:
#    (...)
#      78     # later is linked to the OpenMP runtime to make it possible to introspect
#      79     # it and importing it first would fail if the OpenMP dll cannot be found.
#      80     from . import (
#      81         __check_build,  # noqa: F401
#      82         _distributor_init,  # noqa: F401
#      83     )
# ---> 84     from .base import clone
# ...

# %%
test_ep_img = np.load('../../Craftax/Traces/stone_pickaxe_easy/pixel_obs/craftax_0.npy')

# %%
dir_ = '../../Craftax/Traces/stone_pickaxe_easy'
models = load_models(dir_ + '/start_models')
pu_models = load_pu_models(dir_ + '/pu_start_models')

# %%
test_episode = np.load(f'{dir_}/pca_features_750/craftax_0.npy')
truth = []
#Open the txt file
with open(f'{dir_}/groundTruth/craftax_0', 'r') as f:
    lines = f.read().splitlines()
    truth.extend(lines)

# %%
# def applicable_pu_start_models(models, state, *, return_details=False, eps=0.0):
for i in range(len(test_episode)):
    print(truth[i])
    applicable_pu_start_models(pu_models, test_episode[i], return_details=True)
    print()
# Out:
# wood
# Applicable models (prob ≥ threshold):
#   - wood: p=1.029  thr=0.524  margin=0.505
#
# wood
# Applicable models (prob ≥ threshold):
#   - wood: p=1.182  thr=0.524  margin=0.657
#
# wood
# No applicable models for this state.
#
# wood
# Applicable models (prob ≥ threshold):
#   - wood: p=1.013  thr=0.524  margin=0.489
#
# wood
# No applicable models for this state.
#
# table
# Applicable models (prob ≥ threshold):
#   - table: p=1.206  thr=0.416  margin=0.790
#
# table
# No applicable models for this state.
#
# wood
# Applicable models (prob ≥ threshold):
#   - wood: p=1.050  thr=0.524  margin=0.526
#
# wood
# Applicable models (prob ≥ threshold):
#   - wood: p=0.716  thr=0.524  margin=0.192
#
# wood
# Applicable models (prob ≥ threshold):
#   - wood: p=1.014  thr=0.524  margin=0.489
#
# wood
# No applicable models for this state.
#
# wood_pickaxe
# Applicable models (prob ≥ threshold):
#   - wood_pickaxe: p=0.532  thr=0.378  margin=0.153
#
# wood_pickaxe
# ...

# %%
for i in range(len(test_episode)):
    preds = classify_state_with_start_models(test_episode[i], models, strategy="prob", return_all=True)
    curr_truth = truth[i]

    applicable_skills = [ x['skill'] for x in preds if x['passes_threshold']]

    if len(applicable_skills) == 0:
        applicable_skills =  [classify_state_with_start_models(test_episode[i], models, strategy="prob", return_all=False)[0], 'forced']

    print(f"=====Step {i}=====")
    print("Truth: ", curr_truth)
    print("Applicable Skills: ", applicable_skills)
    print()
# Out:
# =====Step 0=====
# Truth:  wood
# Applicable Skills:  ['wood_', 'forced']
#
# =====Step 1=====
# Truth:  wood
# Applicable Skills:  ['wood_', 'forced']
#
# =====Step 2=====
# Truth:  wood
# Applicable Skills:  ['wood_', 'forced']
#
# =====Step 3=====
# Truth:  wood
# Applicable Skills:  ['stone_', 'forced']
#
# =====Step 4=====
# Truth:  wood
# Applicable Skills:  ['stone_', 'forced']
#
# =====Step 5=====
# Truth:  table
# Applicable Skills:  ['table_', 'forced']
#
# =====Step 6=====
# Truth:  table
# Applicable Skills:  ['wood_', 'forced']
#
# =====Step 7=====
# Truth:  wood
# Applicable Skills:  ['wood_', 'forced']
#
# =====Step 8=====
# Truth:  wood
# Applicable Skills:  ['wood_', 'forced']
#
# =====Step 9=====
# Truth:  wood
# Applicable Skills:  ['wood_', 'forced']
#
# =====Step 10=====
# Truth:  wood
# Applicable Skills:  ['stone_', 'forced']
#
# =====Step 11=====
# Truth:  wood_pickaxe
# Applicable Skills:  ['stone_']
#
# =====Step 12=====
# Truth:  wood_pickaxe
# ...

# %%
end_models = load_models(dir_ + '/end_models')

# %%
#def check_end_state(state_vec, end_models, skill, strategy="prob", return_all=False):
for i in range(len(test_episode)):
    preds = check_end_state(test_episode[i], end_models, "wood_", strategy="prob", return_all=True)
    # def end_state_prob_pu(models_dir: str, skill: str, state) -> dict:
    pu_pred = end_state_prob_pu(dir_ + '/pu_end_models', "wood", test_episode[i])
    curr_truth = truth[i]

    print(f"=====Step {i}=====")
    print("Truth: ", curr_truth)
    print("Can end: ", preds)
    print("PU end prob: ", pu_pred)
    print()
# Out:
# =====Step 0=====
# Truth:  wood
# Can end:  {'skill': 'wood_', 'prob': 0.13798278262033895, 'threshold': 0.5, 'margin': -0.3620172173796611, 'passes_threshold': False}
# PU end prob:  {'prob': 0.2754579509013626, 'threshold': 0.9462855945759858, 'is_end': False, 'margin': -0.6708276436746232}
#
# =====Step 1=====
# Truth:  wood
# Can end:  {'skill': 'wood_', 'prob': 0.1382799124825648, 'threshold': 0.5, 'margin': -0.36172008751743523, 'passes_threshold': False}
# PU end prob:  {'prob': 0.20807280926471572, 'threshold': 0.9462855945759858, 'is_end': False, 'margin': -0.7382127853112701}
#
# =====Step 2=====
# Truth:  wood
# Can end:  {'skill': 'wood_', 'prob': 0.14009388215077803, 'threshold': 0.5, 'margin': -0.359906117849222, 'passes_threshold': False}
# PU end prob:  {'prob': 1.628089191922721, 'threshold': 0.9462855945759858, 'is_end': True, 'margin': 0.6818035973467351}
#
# =====Step 3=====
# Truth:  wood
# ...
